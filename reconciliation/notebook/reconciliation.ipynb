# %%
"""
    Convert excel to markdown
"""
from docling.document_converter import DocumentConverter

file_path = '../data/Banking Statement.xlsx'

def get_docling_result(path):
    if not os.path.exists(path):
        print(f"Error: File does not exist {path}")
        return None

    try:
        converter = DocumentConverter()
        markdown_text = converter.convert(path)
        return markdown_text
    except Exception as e:
        print(f"Error while converting: {e}")
        return None

markdown_data = get_docling_result(file_path)
if markdown_data:
    result = markdown_data.document.export_to_markdown()
    print(f"Convert to markdown successfully")
    # print(result)
else:
    print(f"Parse markdown was getting error")
# Out:
# Convert to markdown successfully

# %%
"""
    Extract 'Thông tin đối soát & Chi tiết giao dịch' in markdown
"""

def format_currency(value):
    formatted = "{:,.2f}".format(value)
    return formatted.replace(',', '.')

def parse_money_from_text(text):
    if not text or str(text).lower() == 'none': return 0.00
    clean_val = str(text).replace(',', '').strip()
    match = re.search(r"(\d+\.?\d*)", clean_val)
    if match:
        return float(match.group(1))
    return 0.00

def extract_banking_data(doc_result):
    if not doc_result or not doc_result.document:
        return ""

    md_text = doc_result.document.export_to_markdown()

    def find_meta(label):
        match = re.search(rf"{label}\s*:\s*\|?\s*([^|\n]+)", md_text)
        return match.group(1).strip() if match else "N/A"

    common_meta = {
        "bank_owner": find_meta("Chủ tài khoản"),
        "account_num": find_meta("Số tài khoản"),
        "cif": find_meta("CIF"),
        "address": find_meta("Địa chỉ").replace(',', '').replace('\n', ' ').strip(),
        "currency": "VND"
    }

    output_strings = []

    for table in doc_result.document.tables:
        df = table.export_to_dataframe(doc=doc_result.document)

        for _, row in df.iterrows():
            cells = [str(c).strip() for c in row.values]

            if any(re.search(r"\d{4}-\d{2}-\d{2}", cell) for cell in cells[:1]):
                try:
                    date_raw = cells[0].split(' ')[0]
                    d_p = date_raw.split('-')
                    date_str = f"{d_p[2]}/{d_p[1]}/{d_p[0]}"

                    ref_num = cells[1]
                    net_val = parse_money_from_text(cells[3])
                    description = cells[4] if len(cells) > 4 else ""

                    tax_match = re.search(r"VAT Amt:.*?=\s*([\d,.]+)\s*VND", description)
                    tax_val = parse_money_from_text(tax_match.group(1)) if tax_match else 0.00

                    gross_match = re.search(r"Gross Amt:.*?=\s*([\d,.]+)\s*VND", description)
                    gross_val = parse_money_from_text(gross_match.group(1)) if gross_match else net_val

                    if gross_val == 0 and net_val > 0:
                        gross_val = net_val

                    record = (
f"Thông tin đối soát:\n"
f"    Ngày giao dịch: {date_str}\n"
f"    Số tham chiếu: {ref_num}\n"
f"    Số tiền ghi có: {format_currency(net_val)}\n"
f"    VAT Amt: {format_currency(tax_val)} VND\n"
f"    Gross Amt: {format_currency(gross_val)} VND\n\n"
f"Chi tiết giao dịch:\n"
f"    Chủ tài khoản: {common_meta['bank_owner']}\n"
f"    Số tài khoản: {common_meta['account_num']}\n"
f"    CIF: {common_meta['cif']}\n"
f"    Địa chỉ: {common_meta['address']}\n"
f"    Loại tiền: {common_meta['currency']}\n"
f"    Mô tả: {description}"
                    )

                    output_strings.append(record)
                except Exception:
                    continue

    return "\n\n---\n\n".join(output_strings)

final_string_data = extract_banking_data(markdown_data)
print(final_string_data)
# Out:
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 5219 - 65354
#     Số tiền ghi có: 156.000.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 156.000.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TKP#P021071000143#333684.300424.230435.nop tien pmh cty 125tr go ba ria
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 34743
#     Số tiền ghi có: 9.798.337.00
#     VAT Amt: 9.907.00 VND
#     Gross Amt: 9.907.318.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C AN LAC BA RIA; MerchNo:11500000457 Gross Amt: Not On-Us=9,907,318.00 VND; VAT Amt:9,907,318.00*1.100%/11 = 9,907.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=13; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 34742
#     Số tiền ghi có: 6.563.913.00
#     VAT Amt: 6.027.00 VND
#     Gross Amt: 6.630.215.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C AN LAC BA RIA; MerchNo:11500000457 Gross Amt: On-Us=6,630,215.00 VND; VAT Amt:6,630,215.00*1.000%/11 = 6,027.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=7; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 34741
#     Số tiền ghi có: 1.693.639.00
#     VAT Amt: 1.712.00 VND
#     Gross Amt: 1.712.476.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:SIEU THI BIG C AN LAC BA RIA; MerchNo:11500000457 Gross Amt: Not On-Us=1,712,476.00 VND; VAT Amt:1,712,476.00*1.100%/11 = 1,712.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=5; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 34740
#     Số tiền ghi có: 214.305.00
#     VAT Amt: 327.00 VND
#     Gross Amt: 217.900.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the JCB:SIEU THI BIG C AN LAC BA RIA; MerchNo:11500000457 Gross Amt: Not On-Us=217,900.00 VND; VAT Amt:217,900.00*1.650%/11 = 327.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=1; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30556
#     Số tiền ghi có: 50.853.506.00
#     VAT Amt: 51.419.00 VND
#     Gross Amt: 51.419.116.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: Not On-Us=51,419,116.00 VND; VAT Amt:51,419,116.00*1.100%/11 = 51,419.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=75; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30555
#     Số tiền ghi có: 14.608.610.00
#     VAT Amt: 13.415.00 VND
#     Gross Amt: 14.756.172.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: On-Us=14,756,172.00 VND; VAT Amt:14,756,172.00*1.000%/11 = 13,415.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=23; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30554
#     Số tiền ghi có: 1.323.706.00
#     VAT Amt: 1.957.00 VND
#     Gross Amt: 1.345.230.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: Not On-Us=1,345,230.00 VND; VAT Amt:1,345,230.00*1.600%/11 = 1,957.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=1; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30553
#     Số tiền ghi có: 18.214.081.00
#     VAT Amt: 18.417.00 VND
#     Gross Amt: 18.416.664.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: Not On-Us=18,416,664.00 VND; VAT Amt:18,416,664.00*1.100%/11 = 18,417.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=24; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30552
#     Số tiền ghi có: 1.876.049.00
#     VAT Amt: 1.723.00 VND
#     Gross Amt: 1.894.999.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: On-Us=1,894,999.00 VND; VAT Amt:1,894,999.00*1.000%/11 = 1,723.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=3; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 30551
#     Số tiền ghi có: 11.186.222.00
#     VAT Amt: 17.061.00 VND
#     Gross Amt: 478.100.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the JCB:EBA TRA VINH; MerchNo: 7400000217 Gross Amt: On-Us=478,100.00 VND, Not On-Us=10,895,791.00 VND; VAT Amt:11,373,891.00*1.650%/11 = 17,061.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=1 Not On-Us=10; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 16177
#     Số tiền ghi có: 91.301.220.00
#     VAT Amt: 92.317.00 VND
#     Gross Amt: 92.316.704.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C BEN TRE; MerchNo: 2400000473 Gross Amt: Not On-Us=92,316,704.00 VND; VAT Amt:92,316,704.00*1.100%/11 = 92,317.00 VND(VAT code:0301472278-005); Code:1005; SLGD: Not On-Us=87; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 16176
#     Số tiền ghi có: 20.730.862.00
#     VAT Amt: 19.037.00 VND
#     Gross Amt: 20.940.265.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C BEN TRE; MerchNo: 2400000473 Gross Amt: On-Us=20,940,265.00 VND; VAT Amt:20,940,265.00*1.000%/11 = 19,037.00 VND(VAT code:0301472278-005); Code:1005; SLGD:On-Us=40; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 16175
#     Số tiền ghi có: 67.254.463.00
#     VAT Amt: 68.002.00 VND
#     Gross Amt: 68.002.490.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:SIEU THI BIG C BEN TRE; MerchNo: 2400000473 Gross Amt: Not On-Us=68,002,490.00 VND; VAT Amt:68,002,490.00*1.100%/11 = 68,002.00 VND(VAT code:0301472278-005); Code:1005; SLGD: Not On-Us=49; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 16174
#     Số tiền ghi có: 6.196.756.00
#     VAT Amt: 9.451.00 VND
#     Gross Amt: 6.300.718.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the JCB:SIEU THI BIG C BEN TRE; MerchNo: 2400000473 Gross Amt: Not On-Us=6,300,718.00 VND; VAT Amt:6,300,718.00*1.650%/11 = 9,451.00 VND(VAT code:0301472278-005); Code:1005; SLGD: Not On-Us=10; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11354
#     Số tiền ghi có: 3.561.974.00
#     VAT Amt: 10.015.00 VND
#     Gross Amt: 1.734.050.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the AMEX:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: On-Us=1,734,050.00 VND, Not On-Us=1,938,088.00 VND; VAT Amt:3,672,138.00*3.000%/11 = 10,015.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=2 Not On-Us=3; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11353
#     Số tiền ghi có: 179.180.085.00
#     VAT Amt: 181.173.00 VND
#     Gross Amt: 181.172.988.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: Not On-Us=181,172,988.00 VND; VAT Amt:181,172,988.00*1.100%/11 = 181,173.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=317; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11352
#     Số tiền ghi có: 27.548.783.00
#     VAT Amt: 25.297.00 VND
#     Gross Amt: 27.827.054.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: On-Us=27,827,054.00 VND; VAT Amt:27,827,054.00*1.000%/11 = 25,297.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=52; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11351
#     Số tiền ghi có: 6.961.600.00
#     VAT Amt: 10.291.00 VND
#     Gross Amt: 7.074.797.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the CUP:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: Not On-Us=7,074,797.00 VND; VAT Amt:7,074,797.00*1.600%/11 = 10,291.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=5; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11350
#     Số tiền ghi có: 382.973.00
#     VAT Amt: 566.00 VND
#     Gross Amt: 389.200.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: Not On-Us=389,200.00 VND; VAT Amt:389,200.00*1.600%/11 = 566.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=1; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11349
#     Số tiền ghi có: 93.492.465.00
#     VAT Amt: 94.532.00 VND
#     Gross Amt: 94.532.321.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: Not On-Us=94,532,321.00 VND; VAT Amt:94,532,321.00*1.100%/11 = 94,532.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=137; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11348
#     Số tiền ghi có: 850.957.00
#     VAT Amt: 781.00 VND
#     Gross Amt: 859.553.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: On-Us=859,553.00 VND; VAT Amt:859,553.00*1.000%/11 = 781.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=1; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11347
#     Số tiền ghi có: 20.210.747.00
#     VAT Amt: 30.825.00 VND
#     Gross Amt: 2.090.672.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the JCB:SIEU THI BIG C-T.H.THANH; MerchNo: 7541154485 Gross Amt: On-Us=2,090,672.00 VND, Not On-Us=18,459,147.00 VND; VAT Amt:20,549,819.00*1.650%/11 = 30,825.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=2 Not On-Us=19; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11346
#     Số tiền ghi có: 175.127.212.00
#     VAT Amt: 177.075.00 VND
#     Gross Amt: 177.075.037.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:GO! - AN LAC; MerchNo: 7541154469 Gross Amt: Not On-Us=177,075,037.00 VND; VAT Amt:177,075,037.00*1.100%/11 = 177,075.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=301; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11345
#     Số tiền ghi có: 20.141.635.00
#     VAT Amt: 18.496.00 VND
#     Gross Amt: 20.345.086.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:GO! - AN LAC; MerchNo: 7541154469 Gross Amt: On-Us=20,345,086.00 VND; VAT Amt:20,345,086.00*1.000%/11 = 18,496.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=31; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11344
#     Số tiền ghi có: 88.775.311.00
#     VAT Amt: 89.763.00 VND
#     Gross Amt: 89.762.701.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:GO! - AN LAC; MerchNo: 7541154469 Gross Amt: Not On-Us=89,762,701.00 VND; VAT Amt:89,762,701.00*1.100%/11 = 89,763.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=133; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11343
#     Số tiền ghi có: 3.957.489.00
#     VAT Amt: 3.634.00 VND
#     Gross Amt: 3.997.464.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the MASTER:GO! - AN LAC; MerchNo: 7541154469 Gross Amt: On-Us=3,997,464.00 VND; VAT Amt:3,997,464.00*1.000%/11 = 3,634.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=3; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 11342
#     Số tiền ghi có: 29.844.832.00
#     VAT Amt: 45.518.00 VND
#     Gross Amt: 6.027.825.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the JCB:GO! - AN LAC; MerchNo: 7541154469 Gross Amt: On-Us=6,027,825.00 VND, Not On-Us=24,317,708.00 VND; VAT Amt:30,345,533.00*1.650%/11 = 45,518.00 VND(VAT code:0301472278); Code:1005; SLGD:On-Us=3 Not On-Us=36; Ngay 30/04/2024.
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 34026
#     Số tiền ghi có: 2.963.915.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 2.963.915.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the tin dung ND not on us :SIEU THI BIG C BEN TRE - So DVCNT: 02400000473;TONG TIEN:2969855.TONG GIAO DICH:4.Tong phi = 0.2*2969855.VAT:5940/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 34025
#     Số tiền ghi có: 26.513.796.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 26.513.796.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND not on us :SIEU THI BIG C BEN TRE - So DVCNT: 02400000473;TONG TIEN:26566930.TONG GIAO DICH:44.Tong phi = 0.2*26566930.VAT:53134/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 34024
#     Số tiền ghi có: 15.633.937.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 15.633.937.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND on us :SIEU THI BIG C BEN TRE - So DVCNT: 02400000473;TONG TIEN:15665268.TONG GIAO DICH:25.Tong phi = 0.2*15665268.VAT:31331/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33846
#     Số tiền ghi có: 20.228.225.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 20.228.225.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND not on us :SIEU THI BIG C AN LAC BA RIA - So DVCNT: 11500000457;TONG TIEN:20268763.TONG GIAO DICH:27.Tong phi = 0.2*20268763.VAT:40538/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33845
#     Số tiền ghi có: 1.606.957.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 1.606.957.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the tin dung ND not on us :SIEU THI BIG C AN LAC BA RIA - So DVCNT: 11500000457;TONG TIEN:1610177.TONG GIAO DICH:1.Tong phi = 0.2*1610177.VAT:3220/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33844
#     Số tiền ghi có: 6.600.300.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 6.600.300.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND on us :SIEU THI BIG C AN LAC BA RIA - So DVCNT: 11500000457;TONG TIEN:6613527.TONG GIAO DICH:13.Tong phi = 0.2*6613527.VAT:13227/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33045
#     Số tiền ghi có: 1.001.094.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 1.001.094.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the tin dung ND not on us :EBA TRA VINH - So DVCNT: 07400000217;TONG TIEN:1003100.TONG GIAO DICH:1.Tong phi = 0.2*1003100.VAT:2006/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33044
#     Số tiền ghi có: 38.992.285.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 38.992.285.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND not on us :EBA TRA VINH - So DVCNT: 07400000217;TONG TIEN:39070426.TONG GIAO DICH:59.Tong phi = 0.2*39070426.VAT:78141/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 33043
#     Số tiền ghi có: 18.493.994.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 18.493.994.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND on us :EBA TRA VINH - So DVCNT: 07400000217;TONG TIEN:18531056.TONG GIAO DICH:31.Tong phi = 0.2*18531056.VAT:37062/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 28717
#     Số tiền ghi có: 856.140.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 856.140.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the tin dung ND not on us :SIEU THI BIG C-T.H.THANH - So DVCNT: 07541154485;TONG TIEN:857856.TONG GIAO DICH:1.Tong phi = 0.2*857856.VAT:1716/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 28716
#     Số tiền ghi có: 24.299.492.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 24.299.492.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND on us :SIEU THI BIG C-T.H.THANH - So DVCNT: 07541154485;TONG TIEN:24348188.TONG GIAO DICH:49.Tong phi = 0.2*24348188.VAT:48696/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 28715
#     Số tiền ghi có: 68.151.450.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 68.151.450.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND not on us :SIEU THI BIG C-T.H.THANH - So DVCNT: 07541154485;TONG TIEN:68288026.TONG GIAO DICH:127.Tong phi = 0.2*68288026.VAT:136576/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 28714
#     Số tiền ghi có: 172.753.220.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 172.753.220.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND not on us :GO! - AN LAC - So DVCNT: 07541154469;TONG TIEN:173099419.TONG GIAO DICH:305.Tong phi = 0.2*173099419.VAT:346199/11.NGAY GD 29/04/2024
#
# ---
#
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 7000 - 28713
#     Số tiền ghi có: 30.286.179.00
#     VAT Amt: 0.00 VND
#     Gross Amt: 30.286.179.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: TTTU the ghi no ND on us :GO! - AN LAC - So DVCNT: 07541154469;TONG TIEN:30346873.TONG GIAO DICH:49.Tong phi = 0.2*30346873.VAT:60694/11.NGAY GD 29/04/2024

# %%
"""
    Encoding 'Thông tin đối soát' to vector 384 dimensions
    Define schema for vector_db & full_metadata = 'Thông tin đối soát + Chi tiết giao dịch'
    Save into Milvus DB
"""

import os
import re
import time
from pymilvus import MilvusClient
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
def process_and_store_to_milvus(final_string_output):
    blocks = [block.strip() for block in final_string_output.split('---') if block.strip()]
    if not blocks:
        print("No data found.")
        return None

    reconcle_list = []
    full_metadata_list = []
    for block in blocks:
        match = re.search(r"Thông tin đối soát:\s*(.*?)(?=Chi tiết giao dịch:|$)", block, re.DOTALL)
        if match:
            recon_content = match.group(1).strip()
            reconcle_list.append(recon_content)
            full_metadata_list.append(block)

    db_name = "../data/vector_db.db"
    COLLECTION_NAME = "reconciliation"

    client = MilvusClient(db_name)

    if client.has_collection(COLLECTION_NAME):
        print(f"Deleting existing collection: '{COLLECTION_NAME}'...")
        client.drop_collection(COLLECTION_NAME)

    print(f"Creating vector for {len(reconcle_list)} transactions...")
    embeddings = model.encode(reconcle_list)

    client.create_collection(
        collection_name=COLLECTION_NAME,
        dimension=384,
        metric_type="COSINE",
        auto_id=True
    )

    insert_data = [
        {
            "vector": embeddings[i],
            "metadata_detail": full_metadata_list[i]
        }
        for i in range(len(reconcle_list))
    ]

    client.insert(collection_name=COLLECTION_NAME, data=insert_data)
    print(f"All vectors created into {db_name} successfully.")

    return client

client = process_and_store_to_milvus(final_string_data)
# Out:
# Creating vector for 42 transactions...
# All vectors created into ../data/vector_db.db successfully.

# %%
"""
    Encoding the embedding vector for Query
    Search by Cosine Similarity in Milvus
    Set the threshold for Cosine Score
"""
def search_transaction(query_text, client):
    query_vector = model.encode([query_text.strip()])

    results = client.search(
        collection_name="reconciliation",
        data=query_vector,
        limit=1,
        output_fields=["metadata_detail"]
    )

    if results and results[0]:
        res = results[0][0]
        score = res['distance']

        print(f"\nCosine: {score:.6f}")

        if score > 0.999:
            print("✅ Result: 100% Matched")
        else:
            print("⚠️ Result: Un-Matched")

        print("-" * 50)
        print(res['entity']['metadata_detail'])

query_transaction = """

    Ngày giao dịch: 30/04/2024
    Số tham chiếu: 9925 - 34743
    Số tiền ghi có: 9.798.337.00
    VAT Amt: 9.907.00 VND
    Gross Amt: 9.907.318.00 VND

"""

search_transaction(query_transaction, client)
# Out:
# Cosine: 1.000000
# ✅ Result: 100% Matched
# --------------------------------------------------
# Thông tin đối soát:
#     Ngày giao dịch: 30/04/2024
#     Số tham chiếu: 9925 - 34743
#     Số tiền ghi có: 9.798.337.00
#     VAT Amt: 9.907.00 VND
#     Gross Amt: 9.907.318.00 VND
#
# Chi tiết giao dịch:
#     Chủ tài khoản: CT TNHH TM& DV SIEU THI BIG C AN LAC
#     Số tài khoản: 71004403751
#     CIF: 101346
#     Địa chỉ: 1231 QLO 1AKP5F.BINHTRI DONG BBINHTAN
#     Loại tiền: VND
#     Mô tả: T/t T/ung the VISA:SIEU THI BIG C AN LAC BA RIA; MerchNo:11500000457 Gross Amt: Not On-Us=9,907,318.00 VND; VAT Amt:9,907,318.00*1.100%/11 = 9,907.00 VND(VAT code:0301472278); Code:1005; SLGD: Not On-Us=13; Ngay 30/04/2024.
